# %%
# %load_ext autoreload
# %autoreload 2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from tqdm import tqdm
import pandas as pd
import imodelsx.process_results
import sys
import datasets
import numpy as np
from copy import deepcopy

from collections import defaultdict
import openai
from typing import List, Tuple
import os
import os.path
from os.path import join
import string
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from typing import List
from IPython.display import display, HTML
import clin.viz
import joblib
openai.api_key_path = '/home/chansingh/.OPENAI_KEY'

# download and extract data
# !wget https://github.com/bepnye/EBM-NLP/raw/master/ebm_nlp_2_00.tar.gz
# !tar -xvf ebm_nlp_2_00.tar.gz

DATA_DIR = 'ebm_nlp_2_00'
DOC_DIR = join(DATA_DIR, 'documents')
ANNOT_DIR = join(DATA_DIR, 'annotations', 'aggregated', 'starting_spans', 'interventions', 'test', 'gold')

annot_fnames = os.listdir(ANNOT_DIR)
doc_ids_gold = sorted([fname.split('.')[0] for fname in annot_fnames])
doc_names = sorted(os.listdir(join(DATA_DIR, 'documents')))
doc_ids = sorted(list(set([doc_name.split('.')[0] for doc_name in doc_names])))
# find doc_ids that are in doc_ids_gold
doc_ids = [doc_id for doc_id in doc_ids if doc_id in doc_ids_gold]

# %%
def get_doc_and_interventions(doc_id):
    doc = open(join(DOC_DIR, doc_id + '.txt'), 'r').read()
    toks = open(join(DOC_DIR, doc_id + '.tokens'), 'r').read()
    annot = open(join(ANNOT_DIR, doc_id + '.AGGREGATED.ann'), 'r').read()
    
    toks_list = toks.split()
    annot_list = np.array([int(i) for i in annot.split()]).astype(int)
    annot_arr = (annot_list > 0).astype(int)

    def find_continguous_sequences(annot_arr: np.ndarray) -> List[Tuple]:
        # return a list of (start, stop) tuples identifying continguous sequences where annot_list is 1
        # e.g. annot_arr = [0, 1, 1, 0, 1, 1, 1, 0, 0, 1] -> [(1, 3), (4, 7), (9, 11)]
        annot_arr = np.concatenate([[0], annot_arr, [0]])
        diffs = np.diff(annot_arr)
        starts = np.where(diffs == 1)[0]
        stops = np.where(diffs == -1)[0]
        return list(zip(starts, stops))

    contiguous_seqs = find_continguous_sequences(annot_arr)

    # get all interventions
    interventions = []
    unique_interventions = []
    for start, stop in contiguous_seqs:
        intervention = toks_list[start:stop]
        if intervention[-1] in string.punctuation:
            intervention = intervention[:-1]
        if intervention[0] in string.punctuation:
            intervention = intervention[1:]
        interventions.append(' '.join(intervention))
        iv_lower = ' '.join(intervention).lower()
        iv_lower_s = iv_lower + 's'
        iv_lower_without_s = iv_lower[:-1] if iv_lower.endswith('s') else iv_lower
        unique_interventions_lower = [x.lower() for x in unique_interventions]
        if not iv_lower in unique_interventions_lower \
            and not iv_lower_s in unique_interventions_lower\
                and not iv_lower_without_s in unique_interventions_lower:
            unique_interventions.append(' '.join(intervention))

    return doc, unique_interventions

docs_and_interventions = [get_doc_and_interventions(doc_id) for doc_id in tqdm(doc_ids)]
docs = [doc for doc, _ in docs_and_interventions]
interventions = [intervention for _, intervention in docs_and_interventions]
df = pd.DataFrame.from_dict({'doc_id': doc_ids, 'interventions': interventions, 'doc': docs})
df.to_csv('ebm_interventions_gold_raw.csv', index=False)

# %% [markdown]
# # Clean up annotations

# %%
ebm_interventions_spans = defaultdict(list)
for i in range(125):
    doc_id = df.iloc[i]['doc_id']

    doc = open(join(DOC_DIR, doc_id + '.txt'), 'r').read()
    toks = open(join(DOC_DIR, doc_id + '.tokens'), 'r').read()
    annot = open(join(ANNOT_DIR, doc_id + '.AGGREGATED.ann'), 'r').read()

    toks_list = toks.split()
    annot_list = np.array([int(i) for i in annot.split()]).astype(float)/2

    if i >= 110:
        color_str = clin.viz.colorize(toks_list, annot_list, char_width_max=60, title=str(i) + " " + doc_id)
        display(HTML(color_str))

    ebm_interventions_spans['doc_id'].append(doc_id)
    ebm_interventions_spans['doc'].append(doc)
    ebm_interventions_spans['toks_list'].append(toks_list)
    ebm_interventions_spans['annot_list'].append(annot_list)
pd.DataFrame(ebm_interventions_spans).to_pickle('ebm_interventions_spans.pkl')
# Out:
# <h3>110 22744141</h3>
# <span class="barcode"; style="color: black; background-color: #fde725">&nbspParent-implemented&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspenhanced&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspmilieu&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspteaching&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspwith&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsppreschool&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspchildren&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspwho&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsphave&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspintellectual&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspdisabilities&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspPURPOSE&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspThe&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsppurpose&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthis&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspstudy&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspwas&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspto&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcompare&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthe&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspeffects&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspenhanced&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspmilieu&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspteaching&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbsp(&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspEMT&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbsp)&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspimplemented&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspby&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspparents&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspand&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptherapists&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspversus&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptherapists&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsponly&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspon&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthe&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsplanguage&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspskills&nbsp</span></br><span class="barcode"; style="color: bla ...
# <h3>111 22865017</h3>
# <span class="barcode"; style="color: black; background-color: #fde725">&nbspRESPECT-PTSD&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp:&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspre-engineering&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspsystems&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspfor&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthe&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspprimary&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcare&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptreatment&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspPTSD&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp,&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspa&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsprandomized&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcontrolled&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptrial&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspBACKGROUND&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspAlthough&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspcollaborative&nbsp</span></br><span class="barcode"; style="color: black; background-color: #21908d">&nbspcare&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspis&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspeffective&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspfor&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptreating&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspdepression&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspand&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspother&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspmental&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspdisorders&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspin&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspprimary&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcare&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp,&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthere&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsphave&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspbeen&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspno&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsprandomized&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptrials&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcollaborative&nbsp</span><span class="barcode"; style="color: black; b ...
# <h3>112 22881991</h3>
# <span class="barcode"; style="color: black; background-color: #fde725">&nbspTeaching&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspemotion&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbsprecognition&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspskills&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspto&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspyoung&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspchildren&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspwith&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspautism&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp:&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspa&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsprandomised&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspcontrolled&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptrial&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspan&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspemotion&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbsptraining&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspprogramme&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspBACKGROUND&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspChildren&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspwith&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspautism&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsphave&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspdifficulties&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspin&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspemotion&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsprecognition&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspand&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspa&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspnumber&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspinterventions&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbsphave&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspbeen&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspdesigned&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspto&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptarget&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthese&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspproblems&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; backg ...
# <h3>113 22897461</h3>
# <span class="barcode"; style="color: black; background-color: #fde725">&nbspEffect&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbsprosuvastatin&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspmonotherapy&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspor&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspin&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcombination&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspwith&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspfenofibrate&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspor&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspω-3&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspfatty&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspacids&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspon&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsplipoprotein&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspsubfraction&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspprofile&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspin&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsppatients&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspwith&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspmixed&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspdyslipidaemia&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspand&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspmetabolic&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspsyndrome&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspBACKGROUND&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspRaised&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptriglycerides&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbsp(&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspTG&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp)&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp,&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspdecreased&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsphigh-density&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsplipoprotein&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcholesterol&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp(&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspHDL-C&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp)&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsplevels&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspand&nbsp</span><span class="barcode"; style="c ...
# <h3>114 22956006</h3>
# <span class="barcode"; style="color: black; background-color: #fde725">&nbspA&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsprandomized&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspdouble-blind&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspplacebo-controlled&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcross-over&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptrial&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthe&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspimpact&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspon&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspquality&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsplife&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcontinuing&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspdexamethasone&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspbeyond&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp24&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsph&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspfollowing&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspadjuvant&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspchemotherapy&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspfor&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspbreast&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcancer&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspUncertainty&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspremains&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspabout&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthe&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspoptimal&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspanti-emetic&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nb
nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspvitamin&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspB1&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbsp)&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspand&nbsp</span><span class="barcode"; style="color: black; background-color: ...
# <h3>121 23417625</h3>
# <span class="barcode"; style="color: black; background-color: #21908d">&nbspSocial&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspskills&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspimprovement&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspin&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspchildren&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspwith&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsphigh-functioning&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspautism&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp:&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspa&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsppilot&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsprandomized&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcontrolled&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptrial&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspHigh-functioning&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspautism&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp(&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspHFA&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp)&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspis&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspcharacterized&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspby&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsppersistent&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspimpairment&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspin&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspsocial&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspinteraction&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspdespite&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspthe&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspabsence&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspmental&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspretardation&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspAlthough&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspan&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspincreasing&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspnumber&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspgroup-based&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspprograms&nbsp</span><span class="barcode"; st ...
# <h3>122 23549581</h3>
# <span class="barcode"; style="color: black; background-color: #fde725">&nbspEffect&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspduloxetine&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspon&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsppain&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp,&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspfunction&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp,&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspand&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspquality&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsplife&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspamong&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsppatients&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspwith&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspchemotherapy-induced&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsppainful&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspperipheral&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspneuropathy&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp:&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspa&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsprandomized&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspclinical&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptrial&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspIMPORTANCE&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspThere&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspare&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspno&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspknown&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspeffective&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptreatments&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspfor&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbsppainful&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspchemotherapy-induced&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspperipheral&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspneuropathy&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspOBJECTIVE&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspTo&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspdetermine&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspthe&nbsp</span><span class="barcode"; sty ...
# <h3>123 23838728</h3>
# <span class="barcode"; style="color: black; background-color: #fde725">&nbspTeacher&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspand&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspchild&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsppredictors&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspachieving&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspIEP&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspgoals&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspof&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspchildren&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspwith&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspautism&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspIt&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspis&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspencouraging&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthat&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspchildren&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspwith&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspautism&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspshow&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspa&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspstrong&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspresponse&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspto&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspearly&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspintervention&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp,&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspyet&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspmore&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspresearch&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspis&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspneeded&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspfor&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspunderstanding&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthe&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspvariability&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspin&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspresponsiveness&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspto&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspspecialized&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspprograms&nbsp</span><span class="barcode"; style="color: black; background-col ...
# <h3>124 23849147</h3>
# <span class="barcode"; style="color: black; background-color: #21908d">&nbspBayesian&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspadaptive&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbsptrials&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspoffer&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspadvantages&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspin&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcomparative&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspeffectiveness&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbsptrials&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp:&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspan&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspexample&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspin&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspstatus&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspepilepticus&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspOBJECTIVE&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspWe&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsppresent&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspa&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspnovel&nbsp</span></br><span class="barcode"; style="color: black; background-color: #21908d">&nbspBayesian&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspadaptive&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspcomparative&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbspeffectiveness&nbsp</span><span class="barcode"; style="color: black; background-color: #21908d">&nbsptrial&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspcomparing&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthree&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsptreatments&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspfor&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspstatus&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspepilepticus&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspthat&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspuses&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspadaptive&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsprandomization&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspwith&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsppotential&nbsp</span></br><span class="barcode"; style="color: black; background-color: #fde725">&nbspearly&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspstopping&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbsp.&nbsp</span><span class="barcode"; style="color: black; background-color: #fde725">&nbspSTUDY&nbsp</span><span class ...

# %%
# paste this dict to start filling in the annotations
d = {doc_ids[i]: interventions[i] for i in range(110, 125)}
d

# %% [markdown]
# ## Read annots and save as pkl

# %%
from ebm_interventions_labels_cleaned import ANNOTS
annot_doc_ids = sorted(list(ANNOTS.keys()))
n_clean = len(ANNOTS)
df_cleaned_rows = defaultdict(list)
for i in range(n_clean):
    doc_id = annot_doc_ids[i]
    row = df.iloc[i]
    assert row['doc_id'] == doc_id, f'{row["doc_id"]} != {doc_id}'
    df_cleaned_rows['doc_id'].append(doc_id)
    df_cleaned_rows['doc'].append(row['doc'].strip())
    df_cleaned_rows['interventions'].append(ANNOTS[doc_id])

# %%
df_cleaned = pd.DataFrame.from_dict(df_cleaned_rows)
joblib.dump(df_cleaned, 'ebm_interventions_cleaned.pkl')
